# %%
print("Hello World")
#python program to swap two variables

x = 10
y = 20
#Creat a temp variable and swap values
temp = x
x = y
y = temp
print(x)
print(y)
# Out:
# Hello World
# 20
# 10

# %% [markdown]
# # Notepad++

# %% [markdown]
# #

# %% [markdown]
# Copmare two python progam
#
#
# ![Screenshot (7).png](data:image/png;base64,...)

# %% [markdown]
# # vs code

# %% [markdown]
# ![Screenshot (8).png](data:image/png;base64,...)
